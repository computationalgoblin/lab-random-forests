# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from scipy.stats import norm
from sklearn.preprocessing import OneHotEncoder

# %%
numerical_data = pd.read_csv(r'files_for_lab\numerical.csv')
categorical_data = pd.read_csv(r'files_for_lab\categorical.csv')
target = pd.read_csv(r'files_for_lab\target.csv')

# %%
display(numerical_data.head())
display(categorical_data.head())
display(target.head())
# Out:
#    TCODE        AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  VIETVETS  \
# 0      0  60.000000       5        9    0         0       39        34
# 1      1  46.000000       6        9   16         0       15        55
# 2      1  61.611649       3        1    2         0       20        29
# 3      0  70.000000       1        4    2         0       23        14
# 4      0  78.000000       3        2   60         1       28         9
#
#    WWIIVETS  LOCALGOV  ...  CARDGIFT  MINRAMNT  MAXRAMNT  LASTGIFT  TIMELAG  \
# 0        18        10  ...        14       5.0      12.0      10.0        4
# 1        11         6  ...         1      10.0      25.0      25.0       18
# 2        33         6  ...        14       2.0      16.0       5.0       12
# 3        31         3  ...         7       2.0      11.0      10.0        9
# 4        53        26  ...         8       3.0      15.0      15.0       14
#
#      AVGGIFT  CONTROLN  HPHONE_D  RFA_2F  CLUSTER2
# ...

# %% [markdown]
# Preprocessing the data

# %%
encoder = OneHotEncoder(drop='first', sparse=False)
encoder.fit(categorical_data)
categorical_encoded = encoder.transform(categorical_data)
categorical = pd.DataFrame(categorical_encoded)

data = pd.concat([numerical_data, categorical, target], axis=1)
# Out:
# c:\Users\angel\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Train_test_splitting

# %%
X = data.drop('TARGET_B', axis=1)
y = data['TARGET_B']

X.columns = X.columns.astype(str)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
smote = SMOTE()
X_train, y_train = smote.fit_resample(X_train, y_train)

# %% [markdown]
# Random Forest Classifier

# %%
rfc = RandomForestClassifier(max_depth=2, random_state=0)
rfc.fit(X_train, y_train)
pred = rfc.predict(X_test)


print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97     22664
#            1       0.52      0.54      0.53      1189
#
#     accuracy                           0.95     23853
#    macro avg       0.75      0.76      0.75     23853
# weighted avg       0.95      0.95      0.95     23853
